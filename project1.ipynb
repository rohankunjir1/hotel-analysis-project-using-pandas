# %%
import pandas as pd
df_bookings=pd.read_csv("C:\\Users\\ROHAN\\OneDrive\\Desktop\\data analytics\\codebasics\\python\\fact_bookings.csv")
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe(percentiles=[0.1,0.2,0.3])
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 10%     16560.000000       1.000000       2.000000       9.000000e+03
# 20%     16563.000000       1.000000       3.000000       9.750000e+03
# 30%     17559.000000       1.000000       3.000000       1.105000e+04
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 10%         4862.000000
# 20%         6500.000000
# 30%         9000.000000
# 50%        11700.000000
# max        45220.000000

# %%
df_bookings.describe(include="all")
# Out:
#               booking_id    property_id booking_date check_in_date  \
# count             134590  134590.000000       134590        134590
# unique            134590            NaN          116            92
# top     May012216558RT11            NaN     8/6/2022      16-07-22
# freq                   1            NaN         1670          2017
# mean                 NaN   18061.113493          NaN           NaN
# std                  NaN    1093.055847          NaN           NaN
# min                  NaN   16558.000000          NaN           NaN
# 25%                  NaN   17558.000000          NaN           NaN
# 50%                  NaN   17564.000000          NaN           NaN
# 75%                  NaN   18563.000000          NaN           NaN
# max                  NaN   19563.000000          NaN           NaN
#
#        checkout_date      no_guests room_category booking_platform  \
# count         134590  134587.000000        134590           134590
# ...

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max(),df_bookings.revenue_generated.median(),
# Out:
# (6500, 28560000, 13500.0)

# %%
df_date=pd.read_csv("C:\\Users\\ROHAN\\OneDrive\\Desktop\\data analytics\\codebasics\\python\\dim_date.csv")
df_hotels=pd.read_csv("C:\\Users\\ROHAN\\OneDrive\\Desktop\\data analytics\\codebasics\\python\\dim_hotels.csv")
df_rooms=pd.read_csv("C:\\Users\\ROHAN\\OneDrive\\Desktop\\data analytics\\codebasics\\python\\dim_rooms.csv")
df_agg_bookings=pd.read_csv("C:\\Users\\ROHAN\\OneDrive\\Desktop\\data analytics\\codebasics\\python\\fact_aggregated_bookings.csv")

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values()
# Out:
# city
# Delhi        5
# Hyderabad    6
# Bangalore    6
# Mumbai       8
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_agg_bookings.groupby("property_id")["successful_bookings"].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
df_agg_bookings.check_in_date[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
# 3        1-May-22
# 12       1-May-22
# 4136    11-Jun-22
# 6209     2-Jul-22
# 8522    25-Jul-22
# 9194    31-Jul-22
# Name: check_in_date, dtype: object

# %%
df_agg_bookings.capacity.max()
# Out:
# 50.0

# %%
# data cleaning

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
# removing -ve values

df_bookings=df_bookings[df_bookings.no_guests>=0]
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_generated.min()
# Out:
# 6500

# %%
df_bookings.revenue_generated.max() #it an outlier
# Out:
# 28560000

# %%
avg,std=df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()
avg,std
# Out:
# (15378.036937686695, 93040.1549314641)

# %%
# its formula to calculate higher limit 
higher_limit=avg+3*std
higher_limit
# Out:
# 294498.50173207896

# %%
df_bookings[df_bookings.revenue_generated<0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings=df_bookings[df_bookings.revenue_generated<higher_limit]

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
# here max value is doubtful
# check max value valid or not
higher_limit=df_bookings.revenue_realized.mean()+3*df_bookings.revenue_realized.std()
higher_limit
# Out:
# 33479.358661845814

# %%
df_bookings[df_bookings.revenue_realized>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
# here rt4 is presidential suit its very expensive so its valid

# %%
# checking higher limit indivisually for rt4 rooms

df_bookings[df_bookings.room_category=="RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
# use higher limit formula
23439+3*9048
# Out:
# 50583

# %%
# it does not hava outlier

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
 # data transformation

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
# occupancy %
df_agg_bookings["occ perce"]=(df_agg_bookings.successful_bookings/df_agg_bookings.capacity)*100 
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#     occ perce
# 0   83.333333
# 1   93.333333
# 2   76.666667
# 3  157.894737
# 4   94.736842

# %%
# ad hoc analysis
# insight generation

# %%
# average occupancy rate in each of the room categories

# %%
# a=df_agg_bookings.groupby("room_category")
# a["occ perce"].mean().round(2)

# %%
df_agg_bookings.groupby("room_category")["occ perce"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ perce, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df=pd.merge(df_agg_bookings,df_rooms,left_on="room_category",right_on="room_id")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#     occ perce room_id room_class
# 0   83.333333     RT1   Standard
# 1   93.333333     RT1   Standard
# 2   76.666667     RT1   Standard
# 3  157.894737     RT1   Standard
# 4   94.736842     RT1   Standard

# %%
# print average occupancy rate per city
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df=pd.merge(df,df_hotels,on="property_id")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
# 3        16559      4-May-22           RT1                   21      30.0
# 4        16559      5-May-22           RT1                   16      30.0
#
#    occ perce room_id room_class  property_name category    city
# 0  83.333333     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 1  66.666667     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 2  56.666667     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 3  70.000000     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 4  53.333333     RT1   Standard  Atliq Exotica   Luxury  Mumbai

# %%
df.groupby("city")["occ perce"].mean().plot(kind="pie")
# Out:
# <Axes: ylabel='occ perce'>

# %%
# when was occupancy better weekday or weekend
df.head()#info not in this
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
# 3        16559      4-May-22           RT1                   21      30.0
# 4        16559      5-May-22           RT1                   16      30.0
#
#    occ perce room_id room_class  property_name category    city
# 0  83.333333     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 1  66.666667     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 2  56.666667     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 3  70.000000     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 4  53.333333     RT1   Standard  Atliq Exotica   Luxury  Mumbai

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df=pd.merge(df,df_date,left_on="check_in_date",right_on="date")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
# 3        16559     10-May-22           RT4                   13      18.0
# 4        19562     10-May-22           RT1                   18      30.0
#
#    occ perce room_id    room_class  property_name category       city  \
# 0  60.000000     RT1      Standard  Atliq Exotica   Luxury     Mumbai
# 1  60.975610     RT2         Elite  Atliq Exotica   Luxury     Mumbai
# 2  62.500000     RT3       Premium  Atliq Exotica   Luxury     Mumbai
# 3  72.222222     RT4  Presidential  Atliq Exotica   Luxury     Mumbai
# 4  60.000000     RT1      Standard      Atliq Bay   Luxury  Bangalore
#
#         date  mmm yy week no  day_type
# 0  10-May-22  May 22    W 20  weekeday
# ...

# %%
df.groupby("day_type")["occ perce"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ perce, dtype: float64

# %%
# in month of june what is occupancy for different citites
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june=df[df["mmm yy"]=="Jun 22"]

# %%
df_june.groupby("city")["occ perce"].mean().round(2).sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
# apeending data into existing data
df_august=pd.read_csv("new_data_august.csv")
df_august.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (6500, 15)

# %%
df_latest=pd.concat([df,df_august],ignore_index=True,axis=0)
df_latest.tail()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ perce room_id room_class  property_name  category       city date  \
# 6502        NaN     NaN   Standard   Atliq Palace  Business  Bangalore  NaN
# 6503        NaN     NaN   Standard   Atliq Grands    Luxury  Bangalore  NaN
# 6504        NaN     NaN   Standard     Atliq City  Business  Bangalore  NaN
# 6505        NaN     NaN   Standard      Atliq Blu    Luxury     Mumbai  NaN
# 6506        NaN     NaN   Standard  Atliq Seasons  Business     Mumbai  NaN
#
#       mmm yy week no  day_type   occ%
# ...

# %%
# print revenue realised per city

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_bookings_all=pd.merge(df_bookings,df_hotels,on="property_id")
df_bookings_all.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %%
# print rev month by month

# %%
df_date["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
pd.merge(df_bookings_all,df_date,left_on="check_in_date",right_on="date")
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
df_date["date"]=pd.to_datetime(df_date["date"])
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_bookings_all["check_in_date"]=pd.to_datetime(df_bookings_all["check_in_date"])
df_bookings_all.head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[248], line 1
# ----> 1 df_bookings_all["check_in_date"]=pd.to_datetime(df_bookings_all["check_in_date"])
#       2 df_bookings_all.head(3)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1108, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1106             result = arg.tz_localize("utc")
#    1107 elif isinstance(arg, ABCSeries):
# -> 1108     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1109     if not cache_array.empty:
#    1110         result = arg.map(cache_array)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
# ...
